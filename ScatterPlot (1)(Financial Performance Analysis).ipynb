# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_excel("C:\\Users\\user\\Desktop\\SalesData.xlsx",sheet_name="myData")

# %%
data
# Out:
#      Order ID Order Date  Customer ID Customer Name          Address  \
# 0        1001 2014-01-27           27    Company AA  789 27th Street
# 1        1002 2014-01-27           27    Company AA  789 27th Street
# 2        1003 2014-01-04            4     Company D   123 4th Street
# 3        1004 2014-01-04            4     Company D   123 4th Street
# 4        1005 2014-01-04            4     Company D   123 4th Street
# ..        ...        ...          ...           ...              ...
# 384      1067 2014-03-08            8     Company H   123 8th Street
# 385      1070 2014-03-03            3     Company C   123 3rd Street
# 386      1071 2014-03-03            3     Company C   123 3rd Street
# 387      1075 2014-03-10           10     Company J  123 10th Street
# 388      1077 2014-03-10           10     Company J  123 10th Street
#
#             City State  ZIP/Postal Code Country/Region       Salesperson  ...  \
# ...

# %%
data.shape
# Out:
# (389, 26)

# %%
data.head()
# Out:
#    Order ID Order Date  Customer ID Customer Name          Address       City  \
# 0      1001 2014-01-27           27    Company AA  789 27th Street  Las Vegas
# 1      1002 2014-01-27           27    Company AA  789 27th Street  Las Vegas
# 2      1003 2014-01-04            4     Company D   123 4th Street   New York
# 3      1004 2014-01-04            4     Company D   123 4th Street   New York
# 4      1005 2014-01-04            4     Company D   123 4th Street   New York
#
#   State  ZIP/Postal Code Country/Region       Salesperson  ... Ship State  \
# 0    NV            99999            USA  Mariya Sergienko  ...         NV
# 1    NV            99999            USA  Mariya Sergienko  ...         NV
# 2    NY            99999            USA    Andrew Cencini  ...         NY
# 3    NY            99999            USA    Andrew Cencini  ...         NY
# 4    NY            99999            USA    Andrew Cencini  ...         NY
#
# ...

# %%
x=data['Quantity']
y=data['Revenue']

# %%
plt.scatter(x,y,color='r',marker="^")
plt.title("Sales Report")
plt.xlabel("Quantity")
plt.ylabel("Revenue")
# Out:
# Text(0, 0.5, 'Revenue')

# %%
std_data=pd.read_excel("C:\\Users\\user\\Desktop\\Student.xlsx",sheet_name="result")
std_data
# Out:
#     Study Hours  Marks
# 0             1     10
# 1             5     50
# 2             2     20
# 3             9     90
# 4             3     30
# 5            10    100
# 6             6     60
# 7             1     10
# 8             2     20
# 9             4     40
# 10            5     50
# 11            3     30
# 12            3     30
# 13            4     40
# 14            9     90
# 15            3     30
# 16            3     30
# 17            6     60
# 18            4     40

# %%
std_data.head()
# Out:
#    Study Hours  Marks
# 0            1     10
# 1            5     50
# 2            2     20
# 3            9     90
# 4            3     30

# %%
std_data.tail()
# Out:
#     Study Hours  Marks
# 14            9     90
# 15            3     30
# 16            3     30
# 17            6     60
# 18            4     40

# %%
std_data
# Out:
#     Study Hours  Marks
# 0             1     10
# 1             5     50
# 2             2     20
# 3             9     90
# 4             3     30
# 5            10    100
# 6             6     60
# 7             1     10
# 8             2     20
# 9             4     40
# 10            5     50
# 11            3     30
# 12            3     30
# 13            4     40
# 14            9     90
# 15            3     30
# 16            3     30
# 17            6     60
# 18            4     40

# %%
std_data.isnull().sum()
# Out:
# Study Hours    0
# Marks          0
# dtype: int64

# %%
std_data.isnull()
# Out:
#     Study Hours  Marks
# 0         False  False
# 1         False  False
# 2         False  False
# 3         False  False
# 4         False  False
# 5         False  False
# 6         False  False
# 7         False  False
# 8         False  False
# 9         False  False
# 10        False  False
# 11        False  False
# 12        False  False
# 13        False  False
# 14        False  False
# 15        False  False
# 16        False  False
# 17        False  False
# 18        False  False

# %%
std_data.head(4)
# Out:
#    Study Hours  Marks
# 0            1     10
# 1            5     50
# 2            2     20
# 3            9     90

# %%
x=std_data['Study Hours']
y=std_data['Marks']

# %%
plt.figure(figsize=(12,8))
plt.scatter(x,y,color="g", marker="^",s=300,edgecolor="r",linewidth=2)
plt.title("Student Marks",fontsize=15)
plt.xlabel("Study Hours",fontsize=15)
plt.ylabel("Marks",fontsize=15)
plt.show()
